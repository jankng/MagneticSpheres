# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# %%
fileName = "singleDipole.txt"
f = open(fileName, "r")
x, y, z, u, v, w = ([] for i in range(0, 6, 1))

for line in f:
    buffer = line.split(" ")
    x.append(float(buffer[1]))
    y.append(float(buffer[2]))
    z.append(float(buffer[3]))
    u.append(float(buffer[4]))
    v.append(float(buffer[5]))
    w.append(float(buffer[6]))
    
print(w)
# Out:
# [6.12323e-17, -0.252857, -0.134865, -0.0437737, 0.0437034, 0.134883, 0.252911, 6.12323e-17]

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(0, 10)
ax.set_ylim3d(0, 10)
ax.set_zlim3d(0, 10)
ax.quiver(x, y, z, u, v, w, length = 0.5, normalize = True, color="red")
ax.scatter(x, y, z, s=500, alpha = 0.5)


plt.show()
plt.savefig('single_normal.eps', format='eps', dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(0, 10)
ax.set_ylim3d(0, 10)
ax.set_zlim3d(1, 5)
ax.quiver(x, y, z, u, v, w, length = 0.5, normalize = True, color="red")


plt.show()
plt.savefig('single_zoom.eps', format='eps', dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">
