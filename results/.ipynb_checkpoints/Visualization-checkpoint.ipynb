# %%
#from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# %%
fileName = "dump.txt"
f = open(fileName, "r")
x, y, z, u, v, w = ([] for i in range(0, 6, 1))

for line in f:
    buffer = line.split(" ")
    x.append(float(buffer[1]))
    y.append(float(buffer[2]))
    z.append(float(buffer[3]))
    u.append(float(buffer[4]))
    v.append(float(buffer[5]))
    w.append(float(buffer[6]))
    print(line)
# Out:
# 0 0 0 100 0.602166 0 0.798371
#
# 1 -0.0774914 0 99.003 0.12087 0 0.992668
#
# 2 0.0807362 0 98.0156 -0.368125 0 0.929776
#
# 3 0.656801 0 97.1982 -0.530082 0 0.847946
#
# 4 1.6568 0 97.1982 -0.0311209 0 -0.999516
#
# 5 2.23287 0 98.0156 -0.029189 0 -0.999574
#
# 6 2.39109 0 99.003 0.0126737 0 -0.99992
#
# 7 2.3136 0 100 0.65366 0 -0.756789

# %%
#%matplotlib notebook

fig, ax = plt.subplots()

ax.scatter(x, z, s=700, alpha = 0.5, c="grey")
ax.quiver(x, z, u, w, color="red")
ax.set(xlim=(-1, 9), ylim=(92, 102))
plt.gca().set_aspect('equal', adjustable='box')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.quiver(x, z, u, w, color="red")
plt.show()
